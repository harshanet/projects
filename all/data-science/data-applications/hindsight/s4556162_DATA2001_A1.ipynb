# %% [markdown]
# NAME: ***Harsha Joshi*** <br>
# STUDENT ID: ***45561623***   <br>
# DATA2001 ASSIGNMENT 1 <br>

# %% [markdown]
# # Question 1

# %% [markdown]
# **Data Preparation: Read the dataset using the “pandas” library. Can you identify the missing data both row- and column-wise in the dataset? Handle data quality issues you found in an appropriate way. Explain how you did it along with the reasons of your choice.**

# %%
# import pandas library 
import pandas as pd

# import numpy and matplotlib
import numpy as np

import matplotlib.pyplot as plt

# load the data
wine_data = pd.read_csv(filepath_or_buffer = 'wine.csv')

# Find the total number of rows
total_rows = wine_data.shape[0]
print("Total number of rows:", total_rows)

# Find the total number of entries (rows)
total_cols = wine_data.shape[1]
print("Total number of columns:", total_cols)

# View first few rows of data
wine_data.head(20)
# Out:
# Total number of rows: 178
# Total number of columns: 14
#     Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0    1.0    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1    1.0    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2    1.0    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3    1.0    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4    1.0    13.24        2.59  2.87  21.0  118.0     2.80        2.69
# 5    1.0    14.20        1.76  2.45  15.2  112.0     3.27        3.39
# 6    1.0    14.39        1.87  2.45  14.6   96.0     2.50        2.52
# 7    1.0    14.06        2.15  2.61  17.6  121.0     2.60        2.51
# 8    1.0    14.83        1.64  2.17  14.0   97.0     2.80        2.98
# 9    1.0    13.86        1.35  2.27  16.0   98.0     2.98        3.15
# 10   1.0    14.10        2.16  2.30  18.0  105.0     2.95        3.32
# 11   1.0    14.12        1.48  2.32  16.8   95.0     2.20        2.43
# ...

# %% [markdown]
# **Description of the Data** <br> <br>
# There are three different types of wines, represented by three numbers: 1, 2 and 3. There are a total of 178 wines, which each type being represented by approximately 60 specimens. <br> <BR>
# The table above shows that there are 13 geometric parameters for wines:
# 1. alcohol
# 2. malic.acid
# 3. ash
# 4. acl
# 5. mg
# 6. phenols
# 7. flavanoids
# 8. nonflavanoid.phenols
# 9. proanth
# 10. color.int
# 11. hue
# 12. OD
# 13. proline

# %%
wine_data.isna().sum()
# Out:
# Wine                    1
# Alcohol                 3
# Malic.acid              1
# Ash                     0
# Acl                     7
# Mg                      1
# Phenols                 4
# Flavanoids              4
# Nonflavanoid.phenols    1
# Proanth                 0
# Color.int               6
# Hue                     0
# OD                      1
# Proline                 7
# dtype: int64

# %% [markdown]
# From the above table, it is evident that all columns (except Ash, Proanth and Hue) have missing values.</br>
#
# <u>**HOW TO HANDLE MISSING VALUES IN THIS CASE?**</u><br>
# Impute the missing data using the best estimate of the missing values based on non-missing values.<br><br>
#
# <u>**METHOD OF IMPUTATION FOR COLUMNS:**</u><br>
# Mean imputation could be suitable for these columns because:
# *  Small amounts of missing data: <br>
# There are only a few missing values (under 10 out of 178), thus mean imputation may have only a minimal impact on the overall dataset. <br> <BR>
# *  Insignificant number of outliers:<br>
# From the boxplots shown below, it is evident that the given columns have very few or no outliers at all. Thus, mean impuation would not introduce significant bias into the data.<br> <br>

# %%
wine_data["Wine"].plot.box(vert=False, title="Distribution of Wine")
# Out:
# <Axes: title={'center': 'Distribution of Wine'}>

# %%
wine_data["Alcohol"].plot.box(vert=False, title="Distribution of Alcohol")
# Out:
# <Axes: title={'center': 'Distribution of Alcohol'}>

# %%
wine_data["Malic.acid"].plot.box(vert=False, title="Distribution of Malic.acid")
# Out:
# <Axes: title={'center': 'Distribution of Malic.acid'}>

# %%
wine_data["Acl"].plot.box(vert=False, title="Distribution of Acl")
# Out:
# <Axes: title={'center': 'Distribution of Acl'}>

# %%
wine_data["Mg"].plot.box(vert=False, title="Distribution of Mg")
# Out:
# <Axes: title={'center': 'Distribution of Mg'}>

# %%
wine_data["Phenols"].plot.box(vert=False, title="Distribution of Phenols")
# Out:
# <Axes: title={'center': 'Distribution of Phenols'}>

# %%
wine_data["Flavanoids"].plot.box(vert=False, title="Distribution of Flavanoids")
# Out:
# <Axes: title={'center': 'Distribution of Flavanoids'}>

# %%
wine_data["Nonflavanoid.phenols"].plot.box(vert=False, title="Distribution of Nonflavanoid.phenols")
# Out:
# <Axes: title={'center': 'Distribution of Nonflavanoid.phenols'}>

# %%
wine_data["Color.int"].plot.box(vert=False, title="Distribution of Color.int")
# Out:
# <Axes: title={'center': 'Distribution of Color.int'}>

# %%
wine_data["OD"].plot.box(vert=False, title="Distribution of OD")
# Out:
# <Axes: title={'center': 'Distribution of OD'}>

# %%
wine_data["Proline"].plot.box(vert=False, title="Distribution of Proline")
# Out:
# <Axes: title={'center': 'Distribution of Proline'}>

# %% [markdown]
# **<u>MEAN IMPUTATION ON Wine COLUMN</u>**

# %% [markdown]
# Let's impute `Wine` using mean imputation. Here we'll first calculate mean of the non-missing values, round it to nearest integer, and then fill missing values with the mean.

# %%
# mean of non-missing Wine values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Wine"].mean())

# fill missing area values with the above mean
wine_data["Wine"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Wine"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Alcohol COLUMN</u>**

# %% [markdown]
# Repeat the same process as above to impute the missing values for Alcohol.

# %%
# mean of non-missing Alcohol values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Alcohol"].mean())

# fill missing area values with the above mean
wine_data["Alcohol"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Alcohol"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Malic.acid COLUMN</u>**

# %%
# mean of non-missing Malic.acid values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Malic.acid"].mean())

# fill missing area values with the above mean
wine_data["Malic.acid"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Malic.acid"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Acl COLUMN</u>**

# %%
# mean of non-missing Acl values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Acl"].mean())

# fill missing area values with the above mean
wine_data["Acl"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Acl"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Mg COLUMN</u>**

# %%
# mean of non-missing Mg values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Mg"].mean())

# fill missing area values with the above mean
wine_data["Mg"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Mg"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Phenols COLUMN</u>**

# %%
# mean of non-missing Phenols values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Phenols"].mean())

# fill missing area values with the above mean
wine_data["Phenols"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Phenols"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Flavanoids COLUMN</u>**

# %%
# mean of non-missing Flavanoids values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Flavanoids"].mean())

# fill missing area values with the above mean
wine_data["Flavanoids"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Flavanoids"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Nonflavanoid.phenols COLUMN</u>**

# %%
# mean of non-missing Nonflavanoid.phenols values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Nonflavanoid.phenols"].mean())

# fill missing area values with the above mean
wine_data["Nonflavanoid.phenols"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Nonflavanoid.phenols"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Color.int COLUMN</u>**

# %%
# mean of non-missing Color.int values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Color.int"].mean())

# fill missing area values with the above mean
wine_data["Color.int"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Color.int"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON OD COLUMN</u>**

# %%
# mean of non-missing OD values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["OD"].mean())

# fill missing area values with the above mean
wine_data["OD"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["OD"].isna().sum()
# Out:
# 0

# %% [markdown]
# **<u>MEAN IMPUTATION ON Proline COLUMN</u>**

# %%
# mean of non-missing Proline values
non_missing_area_mean = np.round(wine_data[wine_data.notna()]["Proline"].mean())

# fill missing area values with the above mean
wine_data["Proline"].fillna(non_missing_area_mean, inplace=True)

# verify that there no missing values in the column
wine_data["Proline"].isna().sum()
# Out:
# 0

# %%
# verify that missing values are imputed in 
wine_data.isna().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %% [markdown]
# # Question 2

# %% [markdown]
# **Exploratory Data Analysis (EDA): Perform a detailed univariate and bivariate EDA on the columns in the dataset. Produce plots and report your observation for each plot clearly.**

# %%
# shape of the data
wine_data.shape
# Out:
# (178, 14)

# %%
# concise summary of the dataset
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine                  178 non-null    float64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Acl                   178 non-null    float64
#  5   Mg                    178 non-null    float64
#  6   Phenols               178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanth               178 non-null    float64
#  10  Color.int             178 non-null    float64
#  11  Hue                   178 non-null    object
#  12  OD                    178 non-null    float64
#  13  Proline               178 non-null    float64
# dtypes: float64(13), object(1)
# ...

# %% [markdown]
# ## UNIVARIATE EDA

# %% [markdown]
# Exploring each column in isolation to identify its distribution and/or data quality issues:

# %% [markdown]
# **Alcohol COLUMN**

# %%
# summarise Alcohol
wine_data["Alcohol"].describe()
# Out:
# count    178.000000
# mean      13.004831
# std        0.806145
# min       11.030000
# 25%       12.370000
# 50%       13.050000
# 75%       13.677500
# max       14.830000
# Name: Alcohol, dtype: float64

# %% [markdown]
# ***OBSERVATIONS*** <br>
# * The 'Alcohol' values are in a moderate range and relatively symmetric distribution.
# * A lower standard deviation (0.81) suggests less variability in the "Alochol" values around the mean.
# * The values lie between 11.03 to 14.83 units.

# %%
# view unique Alcohol values
wine_data["Alcohol"].unique()
# Out:
# array([14.23, 13.2 , 13.16, 14.37, 13.24, 14.2 , 14.39, 14.06, 14.83,
#        13.86, 14.1 , 14.12, 13.75, 14.75, 14.38, 13.63, 14.3 , 13.83,
#        14.19, 13.64, 12.93, 13.71, 12.85, 13.5 , 13.05, 13.39, 13.3 ,
#        13.87, 14.02, 13.73, 13.58, 13.68, 13.76, 13.51, 13.48, 13.28,
#        13.07, 14.22, 13.56, 13.41, 13.88, 14.21, 13.9 , 13.94, 13.82,
#        13.77, 13.74, 13.  , 13.29, 13.72, 12.37, 12.33, 12.64, 13.67,
#        12.17, 13.11, 13.34, 12.21, 12.29, 13.49, 12.99, 11.96, 11.66,
#        13.03, 11.84, 12.7 , 12.  , 12.72, 12.08, 12.67, 12.16, 11.65,
#        11.64, 12.69, 11.62, 12.47, 11.81, 12.6 , 12.34, 11.82, 12.51,
#        12.42, 12.25, 12.22, 11.61, 11.46, 12.52, 11.76, 11.41, 11.03,
#        12.77, 11.45, 11.56, 12.07, 12.43, 11.79, 12.04, 12.86, 12.88,
#        12.81, 12.53, 12.84, 13.36, 13.52, 13.62, 12.87, 13.32, 13.08,
#        12.79, 13.23, 12.58, 13.17, 13.84, 12.45, 14.34, 12.36, 13.69,
# ...

# %%
# histogram of 'Alcohol'
wine_data["Alcohol"].plot.hist(grid=False, bins=10, title="Distribution of Alcohol");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Alcohol in most Wine is between 12 - 12.5 units and also between 13 - 14 units.

# %%
# boxplot of 'Alcohol'
wine_data["Alcohol"].plot.box(vert = False, title = "Distribution of Alcohol");

# %% [markdown]
# ***OBSERVATION*** <br>
# There are no outliers as evident from the boxplot.

# %% [markdown]
# **Malic.acid COLUMN**

# %%
# summarise Malic.acid
wine_data["Malic.acid"].describe()
# Out:
# count    178.000000
# mean       2.334157
# std        1.117423
# min        0.740000
# 25%        1.602500
# 50%        1.865000
# 75%        3.082500
# max        5.800000
# Name: Malic.acid, dtype: float64

# %% [markdown]
# ***OBSERVATIONS*** <BR>
# * 'Malic.acid' values in the dataset have a relatively small range (between 0.74 - 5.80 units).
# * The standard deviation (1.12) indicates less variability around the mean.

# %%
# view unique Malic.acid values
wine_data["Malic.acid"].unique()
# Out:
# array([1.71, 1.78, 2.36, 1.95, 2.59, 1.76, 1.87, 2.15, 1.64, 1.35, 2.16,
#        1.48, 1.73, 1.81, 1.92, 1.57, 1.59, 3.1 , 1.63, 3.8 , 1.86, 1.6 ,
#        2.05, 1.77, 1.72, 1.9 , 1.68, 1.5 , 1.66, 1.83, 1.53, 1.8 , 1.65,
#        3.99, 3.84, 1.89, 3.98, 4.04, 3.59, 2.02, 1.75, 1.67, 1.7 , 1.97,
#        1.43, 0.94, 1.1 , 1.36, 1.25, 1.13, 1.45, 1.21, 1.01, 1.17, 1.19,
#        1.61, 1.51, 1.09, 1.88, 0.9 , 2.89, 0.99, 3.87, 0.92, 3.86, 0.89,
#        0.98, 2.06, 1.33, 2.83, 1.99, 1.52, 2.12, 1.41, 1.07, 3.17, 2.08,
#        1.34, 2.45, 2.55, 1.29, 3.74, 2.43, 2.68, 0.74, 1.39, 1.47, 3.43,
#        2.4 , 4.43, 5.8 , 4.31, 2.13, 4.3 , 2.99, 2.31, 3.55, 1.24, 2.46,
#        4.72, 5.51, 2.96, 2.81, 2.56, 4.95, 3.88, 3.57, 5.04, 4.61, 3.24,
#        3.9 , 3.12, 2.67, 3.3 , 5.19, 4.12, 3.03, 3.83, 3.26, 3.27, 3.45,
#        2.76, 4.36, 3.7 , 3.37, 2.58, 4.6 , 2.  , 2.51, 5.65, 3.91, 4.28,
#        4.1 ])

# %%
# histogram of 'Malic.acid'
wine_data["Malic.acid"].plot.hist(grid=False, bins=10, title="Distribution of Malic.acid");

# %% [markdown]
# ***OBSERVATION***<br>
# Most of the Wines have Malic.acid between 1 - 2 units.

# %%
# boxplot of 'Malic.acid'
wine_data["Malic.acid"].plot.box(vert = False, title = "Distribution of Malic.acid");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise Ash
wine_data["Ash"].describe()
# Out:
# count    178.000000
# mean       2.366517
# std        0.274344
# min        1.360000
# 25%        2.210000
# 50%        2.360000
# 75%        2.557500
# max        3.230000
# Name: Ash, dtype: float64

# %%
# view unique Ash values
wine_data["Ash"].unique()
# Out:
# array([2.43, 2.14, 2.67, 2.5 , 2.87, 2.45, 2.61, 2.17, 2.27, 2.3 , 2.32,
#        2.41, 2.39, 2.38, 2.7 , 2.72, 2.62, 2.48, 2.56, 2.28, 2.65, 2.36,
#        2.52, 3.22, 2.8 , 2.21, 2.84, 2.55, 2.1 , 2.51, 2.31, 2.12, 2.59,
#        2.29, 2.44, 2.4 , 2.04, 2.6 , 2.42, 2.68, 2.25, 2.46, 1.36, 2.02,
#        1.92, 2.16, 2.53, 1.7 , 1.75, 2.24, 1.71, 2.23, 1.95, 2.  , 2.2 ,
#        2.58, 2.26, 2.22, 2.74, 1.98, 1.9 , 1.88, 1.94, 1.82, 2.92, 1.99,
#        2.19, 3.23, 2.73, 2.13, 2.78, 2.54, 2.64, 2.35, 2.15, 2.75, 2.69,
#        2.86, 2.37])

# %%
# histogram of 'Ash'
wine_data["Ash"].plot.hist(grid=False, bins=10, title="Distribution of Ash");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Ash in most Wine is between 2.125 - 2.5 units.

# %%
# boxplot of 'Ash'
wine_data["Ash"].plot.box(vert = False, title = "Distribution of Ash");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise Acl
wine_data["Acl"].describe()
# Out:
# count    178.000000
# mean      19.474157
# std        3.272986
# min       10.600000
# 25%       17.250000
# 50%       19.000000
# 75%       21.500000
# max       30.000000
# Name: Acl, dtype: float64

# %%
# view unique Acl values
wine_data["Acl"].unique()
# Out:
# array([15.6, 11.2, 18.6, 16.8, 21. , 15.2, 14.6, 17.6, 14. , 16. , 18. ,
#        11.4, 12. , 17.2, 20. , 16.5, 16.6, 17.8, 25. , 16.1, 17. , 19.4,
#        22.5, 19.1, 19.5, 19. , 20.5, 15.5, 16.2, 18.8, 15. , 17.5, 18.9,
#        17.4, 12.4, 17.1, 16.4, 16.3, 16.7, 10.6, 18.1, 19.6, 24. , 30. ,
#        14.8, 23. , 22.8, 26. , 21.6, 18.5, 22. , 20.7, 21.5, 20.8, 28.5,
#        26.5, 24.5, 25.5, 27. ])

# %%
# histogram of 'Acl'
wine_data["Acl"].plot.hist(grid=False, bins=10, title="Distribution of Acl");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Alcohol in most Wine is between 15 - 25.5 units.

# %%
# boxplot of 'Acl'
wine_data["Acl"].plot.box(vert = False, title = "Distribution of Acl");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise Mg
wine_data["Mg"].describe()
# Out:
# count    178.000000
# mean      99.820225
# std       14.244882
# min       70.000000
# 25%       88.000000
# 50%       98.000000
# 75%      107.000000
# max      162.000000
# Name: Mg, dtype: float64

# %%
# view unique Mg values
wine_data["Mg"].unique()
# Out:
# array([127., 100., 101., 113., 118., 112.,  96., 121.,  97.,  98., 105.,
#         95.,  89.,  91., 102., 120., 115., 108., 116., 126., 124.,  93.,
#         94., 107., 106., 104., 132., 110., 128., 117.,  90., 103., 111.,
#         92.,  88.,  87.,  78., 151.,  86., 139., 136.,  85.,  99.,  84.,
#         70.,  81.,  80., 162., 134., 119.,  82., 122., 123.])

# %%
# histogram of 'Mg'
wine_data["Mg"].plot.hist(grid=False, bins=10, title="Distribution of Mg");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Mg in most Wine is between 80 - 105 units.

# %%
# boxplot of 'Mg'
wine_data["Mg"].plot.box(vert = False, title = "Distribution of Mg");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise Phenols
wine_data["Phenols"].describe()
# Out:
# count    178.000000
# mean       2.285337
# std        0.623924
# min        0.980000
# 25%        1.742500
# 50%        2.310000
# 75%        2.800000
# max        3.880000
# Name: Phenols, dtype: float64

# %%
# view unique Phenols values
wine_data["Phenols"].unique()
# Out:
# array([2.8 , 2.65, 3.85, 3.27, 2.5 , 2.6 , 2.98, 2.95, 2.2 , 3.1 , 3.3 ,
#        2.85, 2.  , 2.7 , 3.  , 2.41, 2.61, 2.48, 2.53, 2.63, 2.4 , 2.86,
#        2.42, 2.35, 2.45, 3.15, 3.25, 2.64, 2.75, 2.72, 3.88, 2.96, 3.2 ,
#        3.4 , 1.98, 2.05, 2.02, 2.1 , 3.5 , 1.89, 2.11, 1.85, 1.1 , 1.88,
#        3.38, 1.61, 1.95, 1.72, 1.9 , 2.83, 1.65, 1.78, 1.92, 1.6 , 1.45,
#        1.38, 3.02, 2.55, 3.52, 2.23, 2.56, 1.68, 2.36, 2.74, 3.18, 1.75,
#        2.46, 1.63, 2.9 , 2.62, 2.22, 1.51, 1.3 , 1.15, 1.7 , 1.62, 1.79,
#        2.32, 1.54, 1.4 , 1.55, 1.5 , 0.98, 1.41, 1.48, 1.8 , 1.74, 2.3 ,
#        1.83, 1.39, 1.35, 1.28, 1.25, 1.59])

# %%
# histogram of 'Phenols'
wine_data["Phenols"].plot.hist(grid=False, bins=10, title="Distribution of Phenols");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Phenols in most Wine is between 1.6 - 2.1 units and also between 2.5 - 3 units.

# %%
# boxplot of 'Phenols'
wine_data["Phenols"].plot.box(vert = False, title = "Distribution of Phenols");

# %% [markdown]
# ***OBSERVATION*** <br>
# There are no outliers as evident from the boxplot.

# %%
# summarise Flavanoids
wine_data["Flavanoids"].describe()
# Out:
# count    178.000000
# mean       2.042360
# std        0.985874
# min        0.340000
# 25%        1.250000
# 50%        2.110000
# 75%        2.875000
# max        5.080000
# Name: Flavanoids, dtype: float64

# %%
# view unique Flavanoids values
wine_data["Flavanoids"].unique()
# Out:
# array([3.06, 2.76, 3.24, 3.49, 2.69, 3.39, 2.52, 2.51, 2.98, 3.15, 3.32,
#        2.43, 3.69, 3.64, 2.91, 3.14, 3.4 , 3.93, 3.03, 3.17, 2.41, 2.88,
#        2.37, 2.61, 2.68, 2.94, 2.19, 2.97, 2.33, 3.25, 3.19, 2.74, 2.53,
#        2.64, 3.04, 3.29, 3.56, 2.63, 3.  , 2.65, 2.92, 3.54, 3.27, 2.99,
#        3.74, 2.79, 2.9 , 2.78, 3.23, 3.67, 0.57, 1.09, 1.41, 1.79, 3.1 ,
#        1.75, 3.18, 2.  , 1.3 , 1.28, 1.02, 2.86, 1.84, 2.89, 2.14, 1.57,
#        2.03, 1.32, 1.85, 2.55, 2.26, 1.58, 1.59, 2.21, 1.94, 1.69, 1.61,
#        1.5 , 1.25, 1.46, 2.25, 2.27, 0.99, 2.5 , 3.75, 2.17, 1.36, 1.64,
#        1.92, 1.76, 2.04, 2.58, 2.01, 2.29, 1.6 , 2.09, 5.08, 2.13, 2.24,
#        1.22, 1.2 , 0.58, 0.66, 0.47, 0.6 , 0.48, 0.5 , 0.52, 0.8 , 0.78,
#        0.55, 0.34, 0.65, 0.76, 1.39, 0.83, 0.63, 1.31, 1.1 , 0.92, 0.56,
#        0.7 , 0.68, 0.84, 0.96, 0.49, 0.61, 0.75, 0.69])

# %%
# histogram of 'Flavanoids'
wine_data["Flavanoids"].plot.hist(grid=False, bins=10, title="Distribution of Flavanoids");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Flavanoids in most Wine is between 0.3 - 0.7 units and also between 2.5 - 3.1 units.

# %%
# boxplot of 'Flavanoids'
wine_data["Flavanoids"].plot.box(vert = False, title = "Distribution of Flavanoids");

# %% [markdown]
# ***OBSERVATION*** <br>
# There are no outliers as evident from the boxplot.

# %%
# summarise Nonflavanoid.phenols
wine_data["Nonflavanoid.phenols"].describe()
# Out:
# count    178.000000
# mean       0.359157
# std        0.127052
# min        0.000000
# 25%        0.262500
# 50%        0.340000
# 75%        0.430000
# max        0.660000
# Name: Nonflavanoid.phenols, dtype: float64

# %%
# view unique Nonflavanoid.phenols values
wine_data["Nonflavanoid.phenols"].unique()
# Out:
# array([0.28, 0.26, 0.3 , 0.24, 0.39, 0.34, 0.31, 0.29, 0.22, 0.43, 0.33,
#        0.4 , 0.32, 0.17, 0.25, 0.27, 0.47, 0.37, 0.42, 0.5 , 0.2 , 0.21,
#        0.19, 0.63, 0.53, 0.45, 0.55, 0.14, 0.13, 0.35, 0.61, 0.48, 0.52,
#        0.58, 0.66, 0.6 , 0.41, 0.  , 0.44, 0.56])

# %%
# histogram of 'Nonflavanoid.phenols'
wine_data["Nonflavanoid.phenols"].plot.hist(grid=False, bins=10, title="Distribution of Nonflavanoid.phenols");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Nonflavanoid.phenols in most Wine is between 0.2 - 0.6 units.

# %%
# boxplot of 'Nonflavanoid.phenols'
wine_data["Nonflavanoid.phenols"].plot.box(vert = False, title = "Distribution of Nonflavanoid.phenols");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise Proanth
wine_data["Proanth"].describe()
# Out:
# count    178.000000
# mean       1.590899
# std        0.572359
# min        0.410000
# 25%        1.250000
# 50%        1.555000
# 75%        1.950000
# max        3.580000
# Name: Proanth, dtype: float64

# %%
# view unique Proanth values
wine_data["Proanth"].unique()
# Out:
# array([2.29, 1.28, 2.81, 2.18, 1.82, 1.97, 1.98, 1.25, 1.85, 2.38, 1.57,
#        1.81, 2.96, 1.46, 1.72, 1.86, 1.66, 2.1 , 1.69, 1.92, 1.45, 1.35,
#        1.76, 1.95, 1.54, 1.36, 1.44, 1.37, 2.08, 2.34, 1.48, 1.7 , 2.03,
#        2.19, 2.14, 2.91, 1.87, 1.68, 1.62, 2.45, 2.04, 0.42, 0.41, 0.62,
#        0.73, 1.03, 2.28, 1.04, 2.5 , 1.96, 1.65, 1.15, 0.95, 2.76, 1.43,
#        1.77, 1.4 , 2.35, 1.56, 1.34, 1.38, 1.64, 1.63, 1.99, 3.28, 1.31,
#        1.42, 2.49, 3.58, 1.22, 1.05, 2.01, 1.53, 1.61, 0.83, 1.83, 1.71,
#        1.9 , 0.94, 0.84, 0.8 , 1.1 , 0.88, 0.81, 0.75, 0.64, 0.55, 1.02,
#        1.14, 1.3 , 0.68, 0.86, 1.26, 1.55, 2.7 , 0.96, 0.97, 1.11, 1.24,
#        1.06, 1.41])

# %%
# histogram of 'Proanth'
wine_data["Proanth"].plot.hist(grid=False, bins=10, title="Distribution of Proanth");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Proanth in most Wine is between 0.7 - 3 units.

# %%
# boxplot of 'Proanth'
wine_data["Proanth"].plot.box(vert = False, title = "Distribution of Proanth");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise Color.int
wine_data["Color.int"].describe()
# Out:
# count    178.000000
# mean       5.039270
# std        2.274107
# min        1.280000
# 25%        3.250000
# 50%        4.850000
# 75%        6.122500
# max       13.000000
# Name: Color.int, dtype: float64

# %%
# view unique Color.int values
wine_data["Color.int"].unique()
# Out:
# array([ 5.64,  4.38,  5.68,  7.8 ,  4.32,  6.75,  5.25,  5.05,  5.2 ,
#         7.22,  5.75,  5.  ,  5.6 ,  5.4 ,  7.5 ,  6.2 ,  6.6 ,  8.7 ,
#         5.65,  4.5 ,  3.8 ,  3.93,  3.52,  3.58,  4.8 ,  4.7 ,  5.7 ,
#         6.9 ,  3.84,  4.2 ,  5.1 ,  4.6 ,  4.25,  3.7 ,  6.13,  4.28,
#         5.43,  4.36,  5.04,  5.24,  4.9 ,  6.1 ,  8.9 ,  7.2 ,  7.05,
#         6.3 ,  5.85,  6.25,  6.38,  6.  ,  6.8 ,  1.95,  3.27,  2.95,
#         5.3 ,  4.68,  3.17,  2.85,  3.05,  3.38,  3.74,  3.35,  3.21,
#         3.4 ,  2.57,  2.5 ,  3.9 ,  2.2 ,  2.62,  2.45,  2.6 ,  2.8 ,
#         1.74,  2.4 ,  3.6 ,  2.15,  3.25,  2.9 ,  2.3 ,  3.3 ,  2.06,
#         2.94,  2.7 ,  2.65,  2.  ,  3.08,  1.9 ,  1.28,  2.08,  2.76,
#         3.94,  3.  ,  2.12,  4.1 ,  5.45,  7.1 ,  3.85,  4.92,  4.35,
#         4.4 ,  8.21,  4.  ,  7.65,  8.42,  9.4 ,  8.6 , 10.8 , 10.52,
#         7.6 ,  7.9 ,  9.01, 13.  , 11.75,  5.88,  5.58,  5.28,  9.58,
# ...

# %%
# histogram of 'Color.int'
wine_data["Color.int"].plot.hist(grid=False, bins=10, title="Distribution of Color.int");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Color.int in most Wine is between 3 - 5 units.

# %%
# boxplot of 'Color.int'
wine_data["Color.int"].plot.box(vert = False, title = "Distribution of Color.int");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# Because Hue has the value 1,02 in the original dataset. It must be replaced and printed out to verify it has been corrected to 1.02
wine_data['Hue'] = wine_data['Hue'].str.replace(",", ".")
wine_data['Hue'] = wine_data['Hue'].astype(float)

# %%
wine_data.head(30)
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0    1.0    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1    1.0    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2    1.0    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3    1.0    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4    1.0    13.24        2.59  2.87  21.0  118.0     2.80        2.69
# 5    1.0    14.20        1.76  2.45  15.2  112.0     3.27        3.39
# 6    1.0    14.39        1.87  2.45  14.6   96.0     2.50        2.52
# 7    1.0    14.06        2.15  2.61  17.6  121.0     2.60        2.51
# 8    1.0    14.83        1.64  2.17  14.0   97.0     2.80        2.98
# 9    1.0    13.86        1.35  2.27  16.0   98.0     2.98        3.15
# 10   1.0    14.10        2.16  2.30  18.0  105.0     2.95        3.32
# 11   1.0    14.12        1.48  2.32  16.8   95.0     2.20        2.43
# ...

# %%
# summarise Hue
wine_data["Hue"].describe()
# Out:
# count    178.000000
# mean       0.957449
# std        0.228572
# min        0.480000
# 25%        0.782500
# 50%        0.965000
# 75%        1.120000
# max        1.710000
# Name: Hue, dtype: float64

# %%
# view unique Hue values
wine_data["Hue"].unique()
# Out:
# array([1.04 , 1.05 , 1.03 , 0.86 , 1.02 , 1.06 , 1.08 , 1.01 , 1.25 ,
#        1.17 , 1.15 , 1.2  , 1.28 , 1.07 , 1.13 , 1.23 , 0.96 , 1.09 ,
#        1.11 , 1.12 , 0.92 , 1.19 , 1.1  , 1.18 , 0.89 , 0.95 , 0.91 ,
#        0.88 , 0.82 , 0.87 , 1.24 , 0.98 , 0.94 , 1.22 , 1.45 , 0.906,
#        1.36 , 1.31 , 0.99 , 1.38 , 1.16 , 0.84 , 0.79 , 1.33 , 1.   ,
#        1.42 , 1.27 , 0.8  , 0.75 , 0.9  , 0.93 , 1.71 , 0.7  , 0.73 ,
#        0.69 , 0.97 , 0.76 , 0.74 , 0.66 , 0.78 , 0.81 , 0.77 , 0.65 ,
#        0.6  , 0.58 , 0.54 , 0.55 , 0.57 , 0.59 , 0.48 , 0.61 , 0.56 ,
#        0.67 , 0.68 , 0.85 , 0.72 , 0.62 , 0.64 ])

# %%
# histogram of 'Hue'
wine_data["Hue"].plot.hist(grid=False, bins=10, title="Distribution of Hue");

# %% [markdown]
# ***OBSERVATION*** <br>
# The Hue in most Wine is between 0.85 - 1.3 units.

# %%
# boxplot of 'Hue'
wine_data["Hue"].plot.box(vert = False, title = "Distribution of Hue");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# summarise OD
wine_data["OD"].describe()
# Out:
# count    178.000000
# mean       2.619382
# std        0.706707
# min        1.270000
# 25%        1.970000
# 50%        2.780000
# 75%        3.170000
# max        4.000000
# Name: OD, dtype: float64

# %%
# view unique OD values
wine_data["OD"].unique()
# Out:
# array([3.92, 3.4 , 3.17, 3.45, 2.93, 2.85, 3.58, 3.55, 2.82, 2.9 , 2.73,
#        3.  , 2.88, 2.65, 2.57, 3.36, 3.71, 3.52, 4.  , 3.63, 3.82, 3.2 ,
#        3.22, 2.77, 3.59, 2.71, 2.87, 3.47, 2.78, 2.51, 2.69, 3.53, 3.38,
#        3.56, 3.35, 3.33, 3.44, 2.75, 3.1 , 2.91, 3.37, 3.26, 3.03, 3.31,
#        2.84, 1.82, 1.67, 1.59, 2.46, 2.23, 2.3 , 3.18, 3.48, 1.93, 3.07,
#        3.16, 3.5 , 3.13, 2.14, 2.48, 2.52, 2.31, 3.12, 3.14, 2.72, 2.01,
#        3.08, 2.26, 3.21, 2.27, 2.06, 3.3 , 2.96, 2.63, 2.74, 2.83, 2.44,
#        3.57, 2.42, 3.02, 2.81, 2.5 , 3.19, 2.12, 3.05, 3.39, 3.69, 3.64,
#        3.28, 1.29, 1.42, 1.36, 1.51, 1.58, 1.27, 1.69, 2.15, 2.47, 2.05,
#        2.  , 1.68, 1.33, 1.86, 1.62, 1.3 , 1.47, 1.55, 1.48, 1.64, 1.73,
#        1.96, 1.78, 2.11, 1.75, 1.56, 1.8 , 1.92, 1.83, 1.71, 1.74, 1.6 ])

# %%
# histogram of 'OD'
wine_data["OD"].plot.hist(grid=False, bins=10, title="Distribution of OD");

# %% [markdown]
# ***OBSERVATION*** <br>
# The OD in most Wine is between 2.6 - 3.6 units.

# %%
# boxplot of 'OD'
wine_data["OD"].plot.box(vert = False, title = "Distribution of OD");

# %%
# summarise Proline
wine_data["Proline"].describe()
# Out:
# count     178.000000
# mean      745.162921
# std       312.686358
# min       278.000000
# 25%       504.000000
# 50%       677.500000
# 75%       961.750000
# max      1680.000000
# Name: Proline, dtype: float64

# %%
# view unique Proline values
wine_data["Proline"].unique()
# Out:
# array([1065., 1050., 1185., 1480.,  735., 1450., 1290., 1295., 1045.,
#        1510., 1280., 1320., 1150., 1547., 1310., 1130., 1680.,  845.,
#         780.,  770., 1035.,  745.,  830., 1195., 1285.,  915., 1515.,
#         990., 1235., 1095.,  880., 1105., 1020.,  760.,  795.,  680.,
#         885., 1080.,  985., 1060., 1260., 1265., 1190., 1375., 1120.,
#         970., 1270.,  520.,  450.,  630.,  420.,  355.,  502.,  510.,
#         750.,  718.,  870.,  410.,  472.,  886.,  428.,  392.,  500.,
#         463.,  278.,  714.,  515.,  495.,  562.,  625.,  480.,  290.,
#         345.,  937.,  660.,  406.,  710.,  438.,  415.,  672.,  315.,
#         488.,  312.,  325.,  607.,  434.,  385.,  407.,  372.,  564.,
#         465.,  365.,  380.,  378.,  352.,  466.,  342.,  580.,  530.,
#         560.,  600.,  650.,  695.,  720.,  590.,  550.,  855.,  425.,
#         640.,  725.,  620.,  570.,  675.,  615.,  685.,  740.,  835.,
#         840.])

# %%
# histogram of 'Proline'
wine_data["Proline"].plot.hist(grid=False, bins=10, title="Distribution of Proline");

# %% [markdown]
# ***OBSERVATION***<br>
# Proline values for majority of the Wines is between 500 - 700 units.

# %%
# boxplot of 'Proline'
wine_data["Proline"].plot.box(vert = False, title = "Distribution of Proline");

# %% [markdown]
# ***OBSERVATION***<br>
# There are only few outliers as evident from the above boxplot. We can simply ignore them as they are insignificant in number in comparison to the rest of the data.

# %%
# distribution of the 'Hue' column values
hueType_distribution = wine_data["Wine"].value_counts()
hueType_distribution

# make a pie chart
hueType_distribution.plot.pie(autopct='%1.2f%%', pctdistance=0.7, radius=1, title="Proportion of different Wine Types");

# %% [markdown]
# ***OBSERVATION***  <BR>
# There 3 different types of Wine (1, 2, 3) are about 33%, 40% and 27% respectively.

# %% [markdown]
# ## BIVARIATE DATA - Categorial Variable Analysis

# %%
import seaborn as sns

# %%
# Count plot for 'Wine'
plt.figure(figsize=(8, 6))
sns.countplot(data=wine_data, x='Wine')
plt.title("Count of Wine Types")
plt.xlabel("Wine")
plt.ylabel("Count")
plt.show()

# %%
# Box plot of 'Alcohol' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Alcohol')
plt.title("Boxplot of Alcohol by Wine")
plt.xlabel("Wine")
plt.ylabel("Alcohol")
plt.show()

# %%
# Box plot of 'Ash' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Ash')
plt.title("Boxplot of Ash by Wine")
plt.xlabel("Wine")
plt.ylabel("Ash")
plt.show()

# %%
# Box plot of 'Mg' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Mg')
plt.title("Boxplot of Mg by Wine")
plt.xlabel("Wine")
plt.ylabel("Mg")
plt.show()

# %%
# Box plot of 'Color.int' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Color.int')
plt.title("Boxplot of Color.int by Wine")
plt.xlabel("Wine")
plt.ylabel("Color.int")
plt.show()

# %%
# Box plot of 'Proline' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Proline')
plt.title("Boxplot of Proline by Wine")
plt.xlabel("Wine")
plt.ylabel("Proline")
plt.show()

# %% [markdown]
# ***OBSERVATION*** <br>
# Wine 1 has the largest alcohol content while Wine 2 has the least. <br>
# Likewise, Wine 1 has the largest Ash, Mg, Color.int and Proline, with Wine 2 having the least Ash, Mg, Color.int and Proline content. Wine 3 is central in both cases.

# %%
# Box plot of 'Phenols' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Phenols')
plt.title("Boxplot of Phenols by Wine")
plt.xlabel("Wine")
plt.ylabel("Phenols")
plt.show()

# %%
# Box plot of 'Flavanoids' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Flavanoids')
plt.title("Boxplot of Flavanoids by Wine")
plt.xlabel("Wine")
plt.ylabel("Flavanoids")
plt.show()

# %%
# Box plot of 'Proanth' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Proanth')
plt.title("Boxplot of Proanth by Wine")
plt.xlabel("Wine")
plt.ylabel("Proanth")
plt.show()

# %%
# Box plot of 'OD' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='OD')
plt.title("Boxplot of OD by Wine")
plt.xlabel("Wine")
plt.ylabel("OD")
plt.show()

# %% [markdown]
# ***OBSERVATION*** <br>
# Wine 1 has the largest phenol content while Wine 3 has the least. <br>
# Likewise, Wine 1 has the largest Flavanoid, Proanth and OD, with Wine 3 having the least Flavanoid, Proanth and OD content. Wine 2 is central in both cases.

# %%
# Box plot of 'Acl' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Acl')
plt.title("Boxplot of Acl by Wine")
plt.xlabel("Wine")
plt.ylabel("Acl")
plt.show()

# %%
# Box plot of 'Nonflavanoid.phenols' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Nonflavanoid.phenols')
plt.title("Boxplot of Nonflavanoid.phenols by Wine")
plt.xlabel("Wine")
plt.ylabel("Nonflavanoid.phenols")
plt.show()

# %% [markdown]
# ***OBSERVATION*** <br>
# Wine 3 has the largest phenol content while Wine 1 has the least. <br>
# Likewise, Wine 3 has the largest Nonflavanoid.phenols, with Wine 1 having the least Nonflavanoid.phenols. Wine 2 is central in both cases.

# %%
# Box plot of 'Malic.acid' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Malic.acid')
plt.title("Boxplot of Malic.acid by Wine")
plt.xlabel("Wine")
plt.ylabel("Malic.acid")
plt.show()

# %%
# Box plot of 'Hue' by 'Wine'
plt.figure(figsize=(10, 6))
sns.boxplot(data=wine_data, x='Wine', y='Hue')
plt.title("Boxplot of Hue by Wine")
plt.xlabel("Wine")
plt.ylabel("Hue")
plt.show()

# %% [markdown]
# ***OBSERVATION*** <br>
# Both Malic.acid and Hue do not correlate directly with each other nor any other variables in this dataset. <br>
# Malic.acid favours Wine 3 significantly, while Hue puts Wine 1 and 2 with the largest quantities.

# %% [markdown]
# # Question 3

# %% [markdown]
# **Find the mean and standard deviation for each type of component for each cultivator of wine and report your findings in a table. Comment on apparent differences between the cultivators of wine (i.e., vignerons).**

# %%
# Define the columns for which you want to calculate mean and standard deviation
columns_to_agg = ['Alcohol', 'Malic.acid', 'Ash', 'Acl']

# Group the data by 'Wine' and calculate mean and standard deviation for the specified columns
result = wine_data.groupby('Wine')[columns_to_agg].agg(['mean', 'std'])

# Reset the index to have 'Wine' as a regular column
result = result.reset_index()

# Rename the columns to include the statistics (mean and std)
result.columns = [f'{col}_{stat}' if col != 'Wine' else col for col, stat in result.columns]

# Display the result
print(result)
# Out:
#    Wine  Alcohol_mean  Alcohol_std  Malic.acid_mean  Malic.acid_std  Ash_mean  \
# 0   1.0     13.735254     0.471638         2.010678        0.688549  2.455593
# 1   2.0     12.301250     0.541469         1.933611        1.008423  2.245278
# 2   3.0     13.165745     0.531048         3.353830        1.090639  2.440426
#
#     Ash_std   Acl_mean   Acl_std
# 0  0.227166  17.169492  2.518912
# 1  0.313265  20.137500  3.310267
# 2  0.185214  21.351064  2.281578

# %%
import pandas as pd

# Define the columns for which you want to calculate mean and standard deviation
columns_to_agg = ['Mg', 'Phenols', 'Flavanoids', 
                  'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue', 'OD', 'Proline']

# Group the data by 'Wine' and calculate mean and standard deviation for the specified columns
result = wine_data.groupby('Wine')[columns_to_agg].agg(['mean', 'std'])

# Reset the index to have 'Wine' as a regular column
result = result.reset_index()

# Rename the columns to include the statistics (mean and std)
result.columns = [f'{col}_{stat}' if col != 'Wine' else col for col, stat in result.columns]

# Display the result
print(result)
# Out:
#    Wine     Mg_mean     Mg_std  Phenols_mean  Phenols_std  Flavanoids_mean  \
# 0   1.0  106.338983  10.498949      2.811695     0.371962         2.982373
# 1   2.0   94.625000  16.647495      2.245000     0.551704         2.071944
# 2   3.0   99.595745  10.828022      1.686383     0.359441         0.817021
#
#    Flavanoids_std  Nonflavanoid.phenols_mean  Nonflavanoid.phenols_std  \
# 0        0.397494                   0.290000                  0.070049
# 1        0.699474                   0.358611                  0.130333
# 2        0.341594                   0.446809                  0.125388
#
#    Proanth_mean  Proanth_std  Color.int_mean  Color.int_std  Hue_mean  \
# 0      1.899322     0.412109        5.505424       1.203219  1.062034
# 1      1.616528     0.609098        3.153472       0.982211  1.049528
# 2      1.164468     0.406110        7.342979       2.305943  0.685106
#
#     Hue_std   OD_mean    OD_std  Proline_mean  Proline_std
# ...

# %% [markdown]
# #### Before analysing the two tables above, it is important to clear out the general definitions in context to the data to understand the results better:
# **Mean**:  mean values indicate the typical or average values of these parameters within each Wine, giving us insight into how each variety differs in terms of these measurements.
# It is a measure of central tendency that provides an idea of the typical or average value within a dataset. <br> <br>
#
# **Standard deviation**:  standard deviations indicates how much the values for these parameters vary within each Wine. A higher standard deviation suggests greater variability, while a lower standard deviation indicates that the values are closer to the mean, and there is less variability.<br> <br>
#
# ***OBSERVATIONS*** <br>
# Based on the provided results, we can make the following observations regarding the apparent differences between the Wine (1, 2, and 3) in terms of their geometric parameters:
#
# * **Alcohol Mean and Standard Deviation:** <br>
# Wine 1 has the most mean alcohol (13.74), indicating more alcohol content on average, while Wine 2 has the smallest (12.30). <br>
# Wine 2 exhibits the highest standard deviation in alcohol (0.54), suggesting greater variability in alcohol content within Wine 2. <br>
# Wine 3 has a similar standard deviation in alcohol content and similar variability (0.53). <br> <br>
#
# * **Malic.acid Mean and Standard Deviation:** <br>
# Wine 3 has the most mean Malic.acid (3.35), indicating more Malic.acid content on average, while Wine 2 has the smallest (1.93). <br>
# Similar to the alcohol parameter, Wine 2 and Wine 3 demonstrate relatively similar and high standard deviations of 1.01 and 1.09 respectively. <br>
# This suggests that these wines have the greatest variabilities in malic.acid content. Wine 1 has a smaller standard deviation of 0.69. <br>
# Thus, Wine 1 has the least variability.  <br> <br>
#
# * **Ash Mean and Standard Deviation:** <br>
# The Ash mean is relatively similar across all varieties.
# The standard deviations for compactness are quite low for all varieties, suggesting that Ash is relatively consistent within each Wine.<br> <br>
#
# * **Acl Mean and Standard Deviation:** <br>
# Wine 3 has the most Acl on average (106.34), followed by Wine 2 (20.14) and Wine 1 (17.17).
# Wine 2 has the highest standard deviation in Acl (3.31), indicating variability in Acl within Wine 2.<br> <br>
#
# * **Mg Mean and Standard Deviation:**<br>
# Unlike the Acl, Wine 1 has the most Mg on average (3.68), followed by Wine 3 (99.60) and Wine 2 (94.63).<br>
# Wine 1 and 3 have relatively similar standard deviation (approximately 10), while Wine 2 has significantly more variability with a standard deviation of 16.65.<br> <br>
#
# * **Phenols Mean and Standard Deviation:**<br>
# Wine 1 and 2 have similar phenol means (2.81 and 2.25 respectively) compared to Wine 3's 1.69.<br>
# The standard deviations quite similar for all the wines, ranging from 0.36 - 0.55, with Wine 1 and 3 having very similar standard deviations.<br> <br>
#
# * **Flavanoids Mean and Standard Deviation:** <br>
# Wine 1 and 2 have similar mean flavanoid content of 2.98 and 2.07, while Wine 3 is significantly lower at 0.82. <br>
# Wine 1 and 3 have similar variability as they both have standard deviations of 0.40 and 0.34 respectively. This is contrasted by Wine 2's <br>
# standard deviation of 0.70 in phenol content, suggesting this varies more for Wine 2. <br> <br>
#
# * **Nonflavanoids.phenols Mean and Standard Deviation:** <br>
# Wine 2 and 3 have the highest average of nonflavanoid phenols with 0.36 and 0.45. However, given that Wine 1 also has an average of nonflavanoid <br>
# phenols content of 0.29, it is quite similar to Wine 2 and 3. <br>
# The standard deviations for this feature are relatively low across all varieties.<br> <br>
#
# * **Proanth Mean and Standard Deviation:** <br>
# Wine 1, 2 and 3 have similar averages of pronath content between 1 and 2. <br>
# Wine 1 and 3 have exact same standard deviation of 0.41, thus exhibiting the same variability. Wine 2's variability is slightly higher at 0.61 <br>
# standard deviation. <br> <br>
#
# * **Color.int Mean and Standard Deviation:** <br>
# Wine 3 has the highest average color intensity at 7.34. It also has the highest variability at a standard deviation of 2.31. <br>
# Wine 1 and 2 have similar standard deviation of 1.20 and 0.98 respectively. The average color intensity differs with Wine 1 having an average <br>
# of 5.51, while Wine 2 is significantly less at 3.15.<br> <br>
#
# * **Hue Mean and Standard Deviation:** <br>
# Wine 1 and 2 have similar average Hues of 1.06 and 1.05, while Wine 3's 0.69 Hue average is slightly lower. <br>
# All three wines have relatively low standard deviations for this feature. <br> <br>
#
# * **OD Mean and Standard Deviation:** <br>
# Wine 1 has the most OD on average with 3.16. Further, Wine 2 and 3 have slightly lower OD averages at 2.79 and 1.68. <br>
# The standard deviations for the feature are relatively similar across these varieties from 0.27 - 0.49. <br> <br>
#
# * **Proline Mean and Standard Deviation:** <br>
# Wine 1's proline content is sigificantly higher on average (1108.17) than Wine 2 (520.24) and Wine 3 (634.04). <br>
# Similar, standard deviation for Wine 1 is also the greatest variability at 230.04. Furthermore, both Wine 2 and 3 have proportionally similar <br>
# standard deviations at 152.02 and 114.03, with Wine 2 having a greater standard deviation despite having a lower average. <br> <br>
#
# Overall, Wine 1 and 3 demonstrate the highest means and standard deviations/variabilities. Wine 2 generally has smaller and less variable kernels. Wine 3 has slightly lower means and less variability in comparison to Wine 1, but higher with regards to Wine 2. These differences in geometric parameters can provide insights into the distinct characteristics of each Wine, which may have implications for research purposes.

# %% [markdown]
# ## Question 4

# %% [markdown]
# **Find the correlation among the numerical columns for each cultivator. Produce visualisations for the correlations and explain the observed results.**

# %%
wine_data.columns
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
#!pip install seaborn
#!pip install --upgrade pip
import seaborn as sns

# %%
# Select the columns of interest
selected_columns = ['Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols', 'Flavanoids', 'Nonflavanoid.phenols',
                   'Proanth', 'Color.int', 'Hue', 'OD', 'Proline']
selected_data = wine_data[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_data.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap for Selected Variables")
plt.show()

# %% [markdown]
# ***OBSERVATIONS from the correlation heatmap***<br>
#
# 1. ***Positive Correlations*** (shown  by darker shades of red): <br>
# 'Phenols' and 'Flavanoids' have a positive (strong) correlation. Hence, as expected, larger areas generally lead to larger perimeters. <br>
# 'Hue' and 'OD' have a positive correlation, indicating that longer kernels tend to be wider as well. <br> <br>
#
# 2. ***Negative Correlations:*** <br>
# There are no strong negative (indicated by -1) correlations among the selected variables. <br> <br>
#
# 3. ***Weak Correlations*** (shown by darker shades of blue): <br>
# 'Malic.acid' has weak correlations with most other variables, indicating that it might not have a strong linear relationship with the other attributes. It has the darkest shades of blue relative to the entire dataset. <br>
# 'Acl', 'Mg' and 'Color.int' show weak correlations with other variables.

# %%
# Plot scatter plots for various pairs of variables
sns.pairplot(wine_data)
plt.suptitle("Pairwise Scatter Plots")
plt.show()

# %% [markdown]
# ***OBSERVATION***<br>
# The above pairwise scatterplot confirms the observations from the correlation heatmap given before:
#
# * ***Positive Correlation - scatterplot are arranged in upward-sloping pattern:*** <br>
# 'Flavanoids' has a strong correlation with 'Phenols' and 'OD'. This indicates, if one variable increases, the other tends to increase as well. <br> <br>
#
# * ***Negative Correlation - scatterplot arranged in downward sloping pattern:***<br>
# There are no strong negative correlations amoung the given variables. <br><br>
#
# * ***Weak Correlation - scatterplots are spread out without a clear trend:***<br>
# 'Malic.acid' and 'Proline' show weak correlation with other variables.

# %%
wine_data.groupby('Wine').cov()
# Out:
#                              Alcohol  Malic.acid       Ash         Acl  \
# Wine
# 1.0  Alcohol                0.222443   -0.010181 -0.015642   -0.383216
#      Malic.acid            -0.010181    0.474100  0.004101    0.294883
#      Ash                   -0.015642    0.004101  0.051604    0.310932
#      Acl                   -0.383216    0.294883  0.310932    6.344915
#      Mg                     0.679912    0.573387  0.912382    8.560520
#      Phenols                0.053844   -0.013982 -0.000461   -0.213516
#      Flavanoids             0.078168   -0.052352 -0.006362   -0.284219
#      Nonflavanoid.phenols   0.001376   -0.004310  0.007414    0.044569
#      Proanth                0.053259   -0.022927 -0.013619   -0.159624
#      Color.int              0.223187   -0.218857 -0.050536   -0.725849
#      Hue                    0.005099   -0.033684  0.006330    0.004098
#      OD                     0.012755    0.042595 -0.006618   -0.063172
# ...

# %% [markdown]
# #### Pearson Correlation Coefficient

# %%
wine_data.groupby('Wine').corr().style.background_gradient(cmap = 'Greens')
# Out:
# <style type="text/css">
# #T_8f640_row0_col0, #T_8f640_row1_col1, #T_8f640_row2_col2, #T_8f640_row3_col3, #T_8f640_row4_col4, #T_8f640_row5_col5, #T_8f640_row6_col6, #T_8f640_row7_col7, #T_8f640_row8_col8, #T_8f640_row9_col9, #T_8f640_row10_col10, #T_8f640_row11_col11, #T_8f640_row12_col12, #T_8f640_row13_col0, #T_8f640_row14_col1, #T_8f640_row15_col2, #T_8f640_row16_col3, #T_8f640_row17_col4, #T_8f640_row18_col5, #T_8f640_row19_col6, #T_8f640_row20_col7, #T_8f640_row21_col8, #T_8f640_row22_col9, #T_8f640_row23_col10, #T_8f640_row24_col11, #T_8f640_row25_col12, #T_8f640_row26_col0, #T_8f640_row27_col1, #T_8f640_row28_col2, #T_8f640_row29_col3, #T_8f640_row30_col4, #T_8f640_row31_col5, #T_8f640_row32_col6, #T_8f640_row33_col7, #T_8f640_row34_col8, #T_8f640_row35_col9, #T_8f640_row36_col10, #T_8f640_row37_col11, #T_8f640_row38_col12 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# #### Spearman Correlation Coefficient

# %%
wine_data.groupby('Wine').corr(method = 'spearman').style.background_gradient(cmap = 'Purples')
# Out:
# <style type="text/css">
# #T_d554f_row0_col0, #T_d554f_row1_col1, #T_d554f_row2_col2, #T_d554f_row3_col3, #T_d554f_row4_col4, #T_d554f_row5_col5, #T_d554f_row6_col6, #T_d554f_row7_col7, #T_d554f_row8_col8, #T_d554f_row9_col9, #T_d554f_row10_col10, #T_d554f_row11_col11, #T_d554f_row12_col12, #T_d554f_row13_col0, #T_d554f_row14_col1, #T_d554f_row15_col2, #T_d554f_row16_col3, #T_d554f_row17_col4, #T_d554f_row18_col5, #T_d554f_row19_col6, #T_d554f_row20_col7, #T_d554f_row21_col8, #T_d554f_row22_col9, #T_d554f_row23_col10, #T_d554f_row24_col11, #T_d554f_row25_col12, #T_d554f_row26_col0, #T_d554f_row27_col1, #T_d554f_row28_col2, #T_d554f_row29_col3, #T_d554f_row30_col4, #T_d554f_row31_col5, #T_d554f_row32_col6, #T_d554f_row33_col7, #T_d554f_row34_col8, #T_d554f_row35_col9, #T_d554f_row36_col10, #T_d554f_row37_col11, #T_d554f_row38_col12 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_d554f_row0_col1, #T_d554f_row18_col3, #T_d554f_row27_col3 {
#   background-color: #cfd0e6;
# ...

# %% [markdown]
# #### Kendall Correlation Coefficient

# %%
wine_data.groupby('Wine').corr(method = 'kendall').style.background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_d8a26_row0_col0, #T_d8a26_row1_col1, #T_d8a26_row2_col2, #T_d8a26_row3_col3, #T_d8a26_row4_col4, #T_d8a26_row5_col5, #T_d8a26_row6_col6, #T_d8a26_row7_col7, #T_d8a26_row8_col8, #T_d8a26_row9_col9, #T_d8a26_row10_col10, #T_d8a26_row11_col11, #T_d8a26_row12_col12, #T_d8a26_row13_col0, #T_d8a26_row14_col1, #T_d8a26_row15_col2, #T_d8a26_row16_col3, #T_d8a26_row17_col4, #T_d8a26_row18_col5, #T_d8a26_row19_col6, #T_d8a26_row20_col7, #T_d8a26_row21_col8, #T_d8a26_row22_col9, #T_d8a26_row23_col10, #T_d8a26_row24_col11, #T_d8a26_row25_col12, #T_d8a26_row26_col0, #T_d8a26_row27_col1, #T_d8a26_row28_col2, #T_d8a26_row29_col3, #T_d8a26_row30_col4, #T_d8a26_row31_col5, #T_d8a26_row32_col6, #T_d8a26_row33_col7, #T_d8a26_row34_col8, #T_d8a26_row35_col9, #T_d8a26_row36_col10, #T_d8a26_row37_col11, #T_d8a26_row38_col12 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ***OBSERVATIONS*** - Comparing Pearson, Spearman and Kendall Correlation Coefficient <br>
#
# * **Stronger Correlations** (values approximately between 0.4 - 0.9):<br>
# All 3 correlation coeffcients show a strong correlation between phenol, flavanoids and color.int values for the 3 types of Wines (this is indicated with the darker shades of the respective colours). <br> <br>
#
# * **Weaker Correlations** (values < 0.4):<BR>
# Malic.acid and Hue are mostly weakly related to other variables for all the 3 types of Wines. Majority of the variables aside for the stronger correlations are weaker ones. (this is indicated with the lighter shades of the respective colours). <br>

# %% [markdown]
# ## Question 5

# %% [markdown]
# **Perform k-means clustering on the data. Comment on the number of clusters chosen, on possible limitations, and on any form of uncertainty about the results. Are the results in agreement with what you observed in the EDA?**

# %% [markdown]
# ***NOTE: please run Method 2 before running Method 1 to view the relevant plots.***

# %% [markdown]
# Based on the correlations among columns discussed under bivariate EDA, we are selecting pairs of columns that have meaningful relationships.
#
# ***Strong Positive Correlations:*** <br>
#
# 1. 'Phenols' and 'Flavanoids':<br>
# These two variables have a strong positive correlation. Consider performing K-means clustering on this pair to explore how the combined information of phenols and flavanoids impacts cluster formation.<br> <br>
#
# 2. 'Alcohol' and 'Ash':<br>
# These two variables have a strong positive correlation. Consider performing K-means clustering on this pair to explore how the combined information of color.int and flavanoids impacts cluster formation.<br> <br>
#
# ***Weak Correlations:***<br>
#
# 1. 'Malic.acid' and 'Hue' with other variables:<br>
# 'Malic.acid' and 'Hue' show weak correlations with other variables. Consider exploring K-means clustering using these attributes individually to understand their impact on cluster patterns.<br> <br>

# %% [markdown]
# ### Method 1 - Perform K-means on pairs with meaningful correlations

# %%
import matplotlib.pyplot as plt

# Choose two features for visualisation (e.g., 'Phenols' and 'Flavanoids')
feature1 = 'Phenols'
feature2 = 'Flavanoids'

# Create a scatter plot of the chosen features colored by cluster
plt.figure(figsize=(10, 8))
for cluster in range(3):
    cluster_data = result_df[result_df['Cluster'] == cluster]
    plt.scatter(cluster_data[feature1], cluster_data[feature2], label=f'Cluster {cluster}')
    
plt.title(f'K-Means Clustering Results ({feature1} vs. {feature2})')
plt.xlabel(feature1)
plt.ylabel(feature2)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ***OBSERVATIONS*** <BR>
# * There are 3 clusters - Cluster 0, Cluster 1 and Cluster 2. <BR>
# * Cluster 0: Values approximately range from 1.00 - 3.00 units. <BR>
# * Cluster 1: Values approximately range from 1.50 - 3.50 units. <BR>
# * Cluster 2: Values approximately ranger from 2.00 - 3.50 units. <BR>
# * The slope is positive but the points are scattered. This shows that phenols and flavanoid values are positively correlated (as discussed in previous sections of EDA).

# %%
import matplotlib.pyplot as plt

# Choose two features for visualization (e.g., Phenols' and 'Flavanoids')
feature1 = 'Alcohol'
feature2 = 'Ash'

# Create a scatter plot of the chosen features colored by cluster
plt.figure(figsize=(10, 8))
for cluster in range(3):
    cluster_data = result_df[result_df['Cluster'] == cluster]
    plt.scatter(cluster_data[feature1], cluster_data[feature2], label=f'Cluster {cluster}')
    
plt.title(f'K-Means Clustering Results ({feature1} vs. {feature2})')
plt.xlabel(feature1)
plt.ylabel(feature2)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ***OBSERVATIONS***<BR>
# * There are 3 clusters, but they are not clearly distinct.
# * The points are scattered without following any general trend, hence this shows that color.int and flavanoids have a weak correlation (similarly shown in the bivarate EDA).
# * There are few outliers that deviate significantly from the typical characteristics of the clusters.

# %% [markdown]
# ### Method 2 - Perform K-means on all columns at once

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Select the numerical columns from wine_data (excluding 'Wine')
numerical_columns = wine_data.drop('Wine', axis=1)

# Apply k-means clustering with k=3
kmeans = KMeans(n_clusters=3, random_state=0)
cluster_labels = kmeans.fit_predict(numerical_columns)

# Create a new DataFrame to store the results
result_df = pd.DataFrame(numerical_columns, columns=numerical_columns.columns)
result_df['Cluster'] = cluster_labels

# Display the result DataFrame with cluster assignments
print(result_df.head())
# Out:
#    Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4    13.24        2.59  2.87  21.0  118.0     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline  Cluster
# 0                  0.28     2.29       5.64  1.04  3.92   1065.0        1
# 1                  0.26     1.28       4.38  1.05  3.40   1050.0        1
# 2                  0.30     2.81       5.68  1.03  3.17   1185.0        1
# 3                  0.24     2.18       7.80  0.86  3.45   1480.0        1
# 4                  0.39     1.82       4.32  1.04  2.93    735.0        2

# %% [markdown]
# * **Choosing the Number of Clusters (k):** <br>
# Since we have three different varieties of Wines (1, 2 and 3), we take with k=3, as we expect there to be three natural clusters. <br> <br>
#
# * **Limitations:**<br>
# K-means assumes that clusters are spherical, equally sized, and have similar densities. It may not work well if these assumptions do not hold in our data.
# The results can be sensitive to the initial placement of cluster centroids. Running the algorithm multiple times with different initialisations can mitigate this issue. <br>
# Outliers can significantly affect the results, so it's essential to handle outliers appropriately, perhaps by removing them or using a different clustering algorithm that is less sensitive to outliers.
# As observed before, we chose to ignore the outliers as they are very few of them and hence won't have a major impact on the rest of the data.<br> <br>
#
# * **Uncertainty:**<br>
# K-means provides a hard assignment of data points to clusters, which means that each data point belongs to only one cluster. <br> <br>

# %% [markdown]
# The clustering is unable to be visualised directly if we have more than 3 columns. However, we can apply a Principal Component Analysis to reduce the space in 2 columns and visualise this instead:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select the numerical columns from wine_data (excluding 'Hue')
numerical_columns = wine_data.drop('Wine', axis=1)

# Standardise the features (important for PCA)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_columns)

# Define the number of components you want after PCA
pca_num_components = 2

# Create a PCA instance with the desired number of components
pca = PCA(n_components=pca_num_components)

# Fit and transform the data using PCA
pca_result = pca.fit_transform(scaled_data)

# Create a DataFrame with the PCA components
pca_df = pd.DataFrame(data=pca_result, columns=[f'PC{i+1}' for i in range(pca_num_components)])

# Apply K-means clustering to the PCA components
kmeans = KMeans(n_clusters=3, random_state=0)
cluster_labels = kmeans.fit_predict(pca_result)

# Add the cluster labels to the PCA DataFrame
pca_df['Cluster'] = cluster_labels

# Create a scatter plot to visualize the clusters
plt.figure(figsize=(10, 8))
plt.scatter(pca_df['PC1'], pca_df['PC2'], c=cluster_labels, cmap='viridis')
plt.title('K-Means Clustering after PCA')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ***OBSERVATIONS***
# * The data points are in a 2d space, with PC1 and PC2 as the x and y axis respectively.
# * The data points have been effectively separated into 3 distinct clusters.
# * The clusters are well separated from each other. This shows that the PCA components have captured meaningful variance in the data, allowing K-means to identify these distinct groupings.

# %% [markdown]
# # Question 6

# %% [markdown]
# **Perform principal component analysis on the data. Comment on the results, plot the percentage of variance explained by each principal component. Also plot the principal components which you think are of interest, report your observations and limitations.**

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Extract numeric features
# X = wine_data.iloc[:, 1:]  # Exclude the first column if it's non-numeric
# Y = wine
numerical = ['Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols', 'Flavanoids', 'Nonflavanoid.phenols', 
            'Proanth', 'Color.int', 'Hue', 'OD', 'Proline']
x = wine_data.loc[:, numerical].values
y = wine_data.loc[:, ['Wine']].values

# Standardize the data
scaler = StandardScaler()
X_std = scaler.fit_transform(x)

# Perform PCA
pca = PCA()
pca.fit(X_std)

# Explained variance ratio
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# Plot the explained variance by each principal component
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.5, align='center', label='Individual Explained Variance')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Components')
plt.legend()
plt.show()

# %% [markdown]
# ***OBSERVATION***<BR>
# The above bar plot visualises the explained variance ratio for each principal component. As more principal components are taken into consideration, the variance returns diminish.

# %%
# Calculate the explained variance ratios and convert to percentages
explained_variance_percentages = explained_variance * 100

# Plot the explained variance as percentages
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(explained_variance_percentages) + 1), explained_variance_percentages, alpha=0.5, align='center', label='Explained Variance (%)')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance (%)')
plt.title('Percentage of Variance Explained by Principal Components')
plt.legend()
plt.show()

# %% [markdown]
# ***OBSERVATION*** <br>
# The above bar plot represents the percentage of variance explained by a principal component. This visualisation provides a better understanding of the variablity of the data.

# %% [markdown]
# ***Plotting the principal components of interest and reporting observations and limitations:***

# %%
# Specify the number of principal components to visualise
components_to_visualize = [1, 2]  #(PC1 and PC2)

# Calculate the PCA components for the selected components
selected_components = pca.transform(X_std)[:, components_to_visualize]

# Create a scatterplot for the selected components
plt.figure(figsize=(10, 6))
plt.scatter(selected_components[:, 0], selected_components[:, 1], alpha=0.5)
plt.xlabel(f'Principal Component {components_to_visualize[0]}')
plt.ylabel(f'Principal Component {components_to_visualize[1]}')
plt.title(f'Scatterplot of Principal Components {components_to_visualize[0]} vs. {components_to_visualize[1]}')
plt.grid(True)
plt.show()

# %% [markdown]
# ***OBSERVATIONS*** <br>
#
# The above scatterplot visualises the relationship between PC1 and PC2. The values are concentrated in the range of -3 and 3 on x axis. This suggests that the principal components are appropriately scaled and effectively capture the essential information in the data without being dominated by extremely large or small values.

# %%
# Specify the number of principal components to visualise
components_to_visualize = [2, 3]  #(PC2 and PC3)

# Calculate the PCA components for the selected components
selected_components = pca.transform(X_std)[:, components_to_visualize]

# Create a scatterplot for the selected components
plt.figure(figsize=(10, 6))
plt.scatter(selected_components[:, 0], selected_components[:, 1], alpha=0.5)
plt.xlabel(f'Principal Component {components_to_visualize[0]}')
plt.ylabel(f'Principal Component {components_to_visualize[1]}')
plt.title(f'Scatterplot of Principal Components {components_to_visualize[0]} vs. {components_to_visualize[1]}')
plt.grid(True)
plt.show()

# %% [markdown]
# ***OBSERVATIONS*** <br>
# Here the data points range between -2 and 2 (for PC2 and PC3) on x axis suggesting that the principal components are well scaled, balanced in their contributions from the original features, and effectively capture the essential variance in the data.

# %%
# Specify the number of principal components to visualise
components_to_visualize = [1, 3]  #(PC1 and PC3)

# Calculate the PCA components for the selected components
selected_components = pca.transform(X_std)[:, components_to_visualize]

# Create a scatterplot for the selected components
plt.figure(figsize=(10, 6))
plt.scatter(selected_components[:, 0], selected_components[:, 1], alpha=0.5)
plt.xlabel(f'Principal Component {components_to_visualize[0]}')
plt.ylabel(f'Principal Component {components_to_visualize[1]}')
plt.title(f'Scatterplot of Principal Components {components_to_visualize[0]} vs. {components_to_visualize[1]}')
plt.grid(True)
plt.show()

# %% [markdown]
# ***OBSERVATIONS*** <br>
#
# The above scatterplot visualizes the relationship between PC1 and PC3. The values are concentrated in the range of -3 and 3 on x axis. This suggests that the principal components are appropriately scaled and effectively capture the essential information in the data without being dominated by extremely large or small values.

# %% [markdown]
# ***CONCLUSION*** <br>
# Given these scatterplots, it is evident that PC2 and PC3 are the two components important to the wine dataset because they are the most correlated.

# %% [markdown]
# ***Limitations:*** <br> <BR>
#
# * **Limited to Two Components:**<br>
# This approach visualises only two principal components at a time, making it suitable for 2D scatterplots. If you are interested in exploring relationships in higher-dimensional spaces, you may need to use techniques like dimensionality reduction or other visualisation methods.<br> <BR>
#
# * **Loss of Dimensionality:**<br>
# By visualising only a subset of principal components, you lose information contained in the other components. The choice of which components to visualise should be based on your specific analysis goals.<br> <BR>
#
# * **Interpretability:**<br>
# Principal components may not have straightforward interpretations in terms of the original features. While you can analyze their loadings to understand their contributions, the meaning of each component may not always be clear.<br> <BR>
#
# * **Data Scaling:**<br>
# PCA assumes that the data is scaled appropriately. Make sure your data is standardised or scaled before applying PCA to ensure meaningful results.<br> <BR>
